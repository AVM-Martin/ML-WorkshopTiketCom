# %% [markdown]
# # INTRO PANDAS

# %%
import pandas as pd

# %%
pd.DataFrame({
    "Name": ["David", "Brandon"],
    "Umur": [21, 22],
})
# Out:
#       Name  Umur
# 0    David    21
# 1  Brandon    22

# %%
pd.DataFrame(
    {
        "Name": ["David", "Brandon"],
        "Umur": [21, 22],
    },
    index=["A", "B"],
)
# Out:
#       Name  Umur
# A    David    21
# B  Brandon    22

# %%
pd.Series([1, 0, 1, 0, 1, 1])
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# dtype: int64

# %%
pd.Series(
    [0, 20, 40, 60, 80],
    index=["E", "D", "C", "B", "A"],
    name="Batas Nilai",
)
# Out:
# E     0
# D    20
# C    40
# B    60
# A    80
# Name: Batas Nilai, dtype: int64

# %%
sample_data = pd.read_csv(
    "https://raw.githubusercontent.com/davidbrandon16/binusMachineLearning/master/sample.csv",
    sep=";",
)

# %%
sample_data.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0  2018                     Level 3                 AA11
# 1  2018                     Level 3                 AA11
# 2  2018                     Level 3                 AA11
# 3  2018                     Level 3                 AA11
# 4  2018                     Level 3                 AA11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0  Horticulture and Fruit Growing  Dollars (millions)           H01
# 1  Horticulture and Fruit Growing  Dollars (millions)           H01
# 2  Horticulture and Fruit Growing  Dollars (millions)           H04
# 3  Horticulture and Fruit Growing  Dollars (millions)           H05
# 4  Horticulture and Fruit Growing  Dollars (millions)           H07
#
#        Variable_category   Value
# 0  Financial performance  4432.0
# 1  Financial performance  4432.0
# 2  Financial performance  4119.0
# 3  Financial performance     NaN
# 4  Financial performance   211.0

# %%
sample_data.tail()
# Out:
#      Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 255  2018                     Level 4                AA141
# 256  2018                     Level 4                AA141
# 257  2018                     Level 4                AA141
# 258  2018                     Level 4                AA141
# 259  2018                     Level 4                AA141
#
#                           Industry_name_NZSIOC       Units Variable_code  \
# 255  Poultry, Deer and Other Livestock Farming  Percentage           H36
# 256  Poultry, Deer and Other Livestock Farming  Percentage           H37
# 257  Poultry, Deer and Other Livestock Farming  Percentage           H39
# 258  Poultry, Deer and Other Livestock Farming  Percentage           H40
# 259  Poultry, Deer and Other Livestock Farming  Percentage           H41
#
#     Variable_category  Value
# 255  Financial ratios  111.0
# 256  Financial ratios   71.0
# 257  Financial ratios   10.0
# 258  Financial ratios    4.0
# 259  Financial ratios   42.0

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 8 columns):
# Year                           260 non-null int64
# Industry_aggregation_NZSIOC    260 non-null object
# Industry_code_NZSIOC           260 non-null object
# Industry_name_NZSIOC           260 non-null object
# Units                          260 non-null object
# Variable_code                  260 non-null object
# Variable_category              260 non-null object
# Value                          251 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 16.4+ KB

# %%
sample_data["Year"]
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 255    2018
# 256    2018
# 257    2018
# 258    2018
# 259    2018
# Name: Year, Length: 260, dtype: int64

# %%
sample_data[["Year"]]
# Out:
#      Year
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# ..    ...
# 255  2018
# 256  2018
# 257  2018
# 258  2018
# 259  2018
#
# [260 rows x 1 columns]

# %%
sample_data[10:20]
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 10  2018                     Level 3                 AA11
# 11  2018                     Level 3                 AA11
# 12  2018                     Level 3                 AA11
# 13  2018                     Level 3                 AA11
# 14  2018                     Level 3                 AA11
# 15  2018                     Level 3                 AA11
# 16  2018                     Level 3                 AA11
# 17  2018                     Level 3                 AA11
# 18  2018                     Level 3                 AA11
# 19  2018                     Level 3                 AA11
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 10  Horticulture and Fruit Growing  Dollars (millions)           H11
# 11  Horticulture and Fruit Growing  Dollars (millions)           H12
# 12  Horticulture and Fruit Growing  Dollars (millions)           H13
# 13  Horticulture and Fruit Growing  Dollars (millions)           H19
# 14  Horticulture and Fruit Growing  Dollars (millions)           H20
# 15  Horticulture and Fruit Growing  Dollars (millions)           H21
# 16  Horticulture and Fruit Growing  Dollars (millions)           H22
# 17  Horticulture and Fruit Growing  Dollars (millions)           H23
# 18  Horticulture and Fruit Growing  Dollars (millions)           H24
# 19  Horticulture and Fruit Growing  Dollars (millions)           H25
#
#         Variable_category    Value
# 10  Financial performance    200.0
# 11  Financial performance    744.0
# 12  Financial performance      0.0
# 13  Financial performance   2408.0
# 14  Financial performance     14.0
# 15  Financial performance    317.0
# 16  Financial performance    317.0
# 17  Financial performance    854.0
# 18     Financial position  13187.0
# 19     Financial position   2352.0

# %%
sample_data.loc[1, "Variable_code"]
# Out:
# 'H01'

# %%
sample_data.loc[
    range(0,10,2),
    ["Variable_code", "Value"],
]
# Out:
#   Variable_code   Value
# 0           H01  4432.0
# 2           H04  4119.0
# 4           H07   211.0
# 6           H08  3579.0
# 8           H10    33.0

# %% [markdown]
# Do not use `and`

# %%
sample_data.loc[
    (sample_data["Units"] == "Percentage") & (sample_data["Value"] > 50)
]
# Out:
#      Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 28   2018                     Level 3                 AA11
# 29   2018                     Level 3                 AA11
# 59   2018                     Level 4                AA111
# 60   2018                     Level 4                AA111
# 90   2018                     Level 3                 AA12
# 91   2018                     Level 3                 AA12
# 94   2018                     Level 3                 AA12
# 122  2018                     Level 4                AA121
# 123  2018                     Level 4                AA121
# 126  2018                     Level 4                AA121
# 156  2018                     Level 3                 AA13
# 157  2018                     Level 3                 AA13
# 187  2018                     Level 4                AA131
# 188  2018                     Level 4                AA131
# 219  2018                     Level 3                 AA14
# 220  2018                     Level 3                 AA14
# 255  2018                     Level 4                AA141
# 256  2018                     Level 4                AA141
#
#                           Industry_name_NZSIOC       Units Variable_code  \
# 28              Horticulture and Fruit Growing  Percentage           H36
# 29              Horticulture and Fruit Growing  Percentage           H37
# 59              Horticulture and Fruit Growing  Percentage           H36
# 60              Horticulture and Fruit Growing  Percentage           H37
# 90        Sheep, Beef Cattle and Grain Farming  Percentage           H36
# 91        Sheep, Beef Cattle and Grain Farming  Percentage           H37
# 94        Sheep, Beef Cattle and Grain Farming  Percentage           H41
# 122       Sheep, Beef Cattle and Grain Farming  Percentage           H36
# 123       Sheep, Beef Cattle and Grain Farming  Percentage           H37
# 126       Sheep, Beef Cattle and Grain Farming  Percentage           H41
# 156                       Dairy Cattle Farming  Percentage           H36
# 157                       Dairy Cattle Farming  Percentage           H37
# 187                       Dairy Cattle Farming  Percentage           H36
# 188                       Dairy Cattle Farming  Percentage           H37
# 219  Poultry, Deer and Other Livestock Farming  Percentage           H36
# 220  Poultry, Deer and Other Livestock Farming  Percentage           H37
# 255  Poultry, Deer and Other Livestock Farming  Percentage           H36
# 256  Poultry, Deer and Other Livestock Farming  Percentage           H37
#
#     Variable_category  Value
# 28   Financial ratios   73.0
# 29   Financial ratios   63.0
# 59   Financial ratios   73.0
# 60   Financial ratios   63.0
# 90   Financial ratios  137.0
# 91   Financial ratios   69.0
# 94   Financial ratios   55.0
# 122  Financial ratios  137.0
# 123  Financial ratios   69.0
# 126  Financial ratios   55.0
# 156  Financial ratios  111.0
# 157  Financial ratios   51.0
# 187  Financial ratios  111.0
# 188  Financial ratios   51.0
# 219  Financial ratios  111.0
# 220  Financial ratios   71.0
# 255  Financial ratios  111.0
# 256  Financial ratios   71.0
