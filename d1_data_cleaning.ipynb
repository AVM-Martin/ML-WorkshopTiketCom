# %% [markdown]
# # DATA CLEANING

# %%
import pandas as pd

# %%
sample_data = pd.read_csv(
    "https://raw.githubusercontent.com/davidbrandon16/binusMachineLearning/master/sample.csv",
    sep=";",
)

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 8 columns):
# Year                           260 non-null int64
# Industry_aggregation_NZSIOC    260 non-null object
# Industry_code_NZSIOC           260 non-null object
# Industry_name_NZSIOC           260 non-null object
# Units                          260 non-null object
# Variable_code                  260 non-null object
# Variable_category              260 non-null object
# Value                          251 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 16.4+ KB

# %%
data_1 = sample_data.drop_duplicates().dropna().reset_index(
    drop=True
).rename(
    columns={
        "Industry_aggregation_NZSIOC": "level",
        "Industry_code_NZSIOC": "code",
        "Industry_name_NZSIOC": "name",
    }
).drop(columns="Year")

# %%
data_1.head()
# Out:
#      level  code                            name               Units  \
# 0  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 1  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 2  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 3  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 4  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
#
#   Variable_code      Variable_category         Value
# 0           H01  Financial performance  4.432000e+09
# 1           H04  Financial performance  4.119000e+09
# 2           H07  Financial performance  2.110000e+08
# 3           H08  Financial performance  3.579000e+09
# 4           H09  Financial performance  1.800000e+08

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 7 columns):
# level                231 non-null object
# code                 231 non-null object
# name                 231 non-null object
# Units                231 non-null object
# Variable_code        231 non-null object
# Variable_category    231 non-null object
# Value                231 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 12.8+ KB

# %%
data_1.columns
# Out:
# Index(['level', 'code', 'name', 'Units', 'Variable_code', 'Variable_category',
#        'Value'],
#       dtype='object')

# %%
data_1.groupby(["level", "name"]).mean()
# Out:
#                                                           Value
# level   name
# Level 3 Dairy Cattle Farming                       1.116443e+10
#         Horticulture and Fruit Growing             2.505578e+09
#         Poultry, Deer and Other Livestock Farming  1.216081e+09
#         Sheep, Beef Cattle and Grain Farming       1.008699e+10
# Level 4 Dairy Cattle Farming                       8.938504e+09
#         Horticulture and Fruit Growing             2.421525e+09
#         Poultry, Deer and Other Livestock Farming  1.175546e+09
#         Sheep, Beef Cattle and Grain Farming       9.761539e+09

# %%
data_1.loc[(data_1.Units == "Dollars (millions)"), "Value"] = data_1.Value * 1000

# %%
data_1.sort_values(by=[
    "name",
    "code",
    "Variable_code",
])
# Out:
#        level   code                                  name               Units  \
# 114  Level 3   AA13                  Dairy Cattle Farming  Dollars (millions)
# 115  Level 3   AA13                  Dairy Cattle Farming  Dollars (millions)
# 116  Level 3   AA13                  Dairy Cattle Farming  Dollars (millions)
# 117  Level 3   AA13                  Dairy Cattle Farming  Dollars (millions)
# 118  Level 3   AA13                  Dairy Cattle Farming  Dollars (millions)
# ..       ...    ...                                   ...                 ...
# 109  Level 4  AA121  Sheep, Beef Cattle and Grain Farming          Percentage
# 110  Level 4  AA121  Sheep, Beef Cattle and Grain Farming          Percentage
# 111  Level 4  AA121  Sheep, Beef Cattle and Grain Farming          Percentage
# 112  Level 4  AA121  Sheep, Beef Cattle and Grain Farming          Percentage
# 113  Level 4  AA121  Sheep, Beef Cattle and Grain Farming          Percentage
#
#     Variable_code      Variable_category         Value
# 114           H01  Financial performance  1.353700e+10
# 115           H04  Financial performance  1.301100e+10
# 116           H05  Financial performance  1.810000e+08
# 117           H07  Financial performance  3.450000e+08
# 118           H08  Financial performance  1.165800e+10
# ..            ...                    ...           ...
# 109           H36       Financial ratios  1.370000e+02
# 110           H37       Financial ratios  6.900000e+01
# 111           H39       Financial ratios  6.000000e+00
# 112           H40       Financial ratios  3.000000e+00
# 113           H41       Financial ratios  5.500000e+01
#
# [231 rows x 7 columns]

# %%
data_2 = sample_data.drop_duplicates().fillna(
    0,
).reset_index(
    drop=True,
).rename(
    columns={
        "Industry_aggregation_NZSIOC": "level",
        "Industry_code_NZSIOC": "code",
        "Industry_name_NZSIOC": "name",
    }
).drop(columns="Year")

# %%
data_2.head()
# Out:
#      level  code                            name               Units  \
# 0  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 1  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 2  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 3  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
# 4  Level 3  AA11  Horticulture and Fruit Growing  Dollars (millions)
#
#   Variable_code      Variable_category   Value
# 0           H01  Financial performance  4432.0
# 1           H04  Financial performance  4119.0
# 2           H05  Financial performance     0.0
# 3           H07  Financial performance   211.0
# 4           H08  Financial performance  3579.0
